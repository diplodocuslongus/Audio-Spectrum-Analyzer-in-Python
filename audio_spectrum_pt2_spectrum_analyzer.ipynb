# %% [markdown]
# # notes
#
# ## poor performances with 2 plots
#
# I couldn't get a waveform in this notebook behaving identically to the pt1 version,  it appears that plotting 2 subplots drastically limits the performances, even when commenting out the fft. There is a lag of several seconds between the actual sound and the modification of the waveform and the spectrum.
#
#
#
# ## modif
#
# Takes into account https://github.com/markjay4k/Audio-Spectrum-Analyzer-in-Python/pull/16

# %%
"""
Notebook for streaming data from a microphone in realtime

audio is captured using pyaudio
then converted from binary data to ints using struct
then displayed using matplotlib

scipy.fftpack computes the FFT

if you don't have pyaudio, then run

>>> pip install pyaudio

note: with 2048 samples per chunk, I'm getting 20FPS
when also running the spectrum, its about 15FPS
"""

import pyaudio
import os
import struct
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack import fft
import time
from tkinter import TclError

# to display in separate Tk window
# %matplotlib tk

# constants
CHUNK = 1024 * 2             # samples per frame
FORMAT = pyaudio.paInt16     # audio format (bytes per sample?)
CHANNELS = 1                 # single channel for microphone
RATE = 44100                 # samples per second

# %%
# create matplotlib figure and axes
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 7))
# fig, ax1 = plt.subplots(1, figsize=(15, 7))


# pyaudio class instance
p = pyaudio.PyAudio()

# stream object to get data from microphone
stream = p.open(
    format=FORMAT,
    channels=CHANNELS,
    rate=RATE,
    input=True,
    output=True,
    frames_per_buffer=CHUNK
)

# variable for plotting
x = np.arange(0, 2 * CHUNK, 2)       # samples (waveform)
xf = np.linspace(0, RATE, CHUNK)     # frequencies (spectrum)

# create a line object with random data
line, = ax1.plot(x, np.random.rand(CHUNK), '-', lw=2)

# Signal range is -32k to 32k
# limiting amplitude to +/- 4k
AMPLITUDE_LIMIT = 4096

# create semilogx line for spectrum
line_fft, = ax2.semilogx(xf, np.random.rand(CHUNK), '-', lw=2)

# format waveform axes
ax1.set_title('AUDIO WAVEFORM')
ax1.set_xlabel('samples')
ax1.set_ylabel('volume')
ax1.set_ylim(0, 255)
# ax1.set_ylim(-AMPLITUDE_LIMIT, AMPLITUDE_LIMIT)
ax1.set_xlim(0, 2 * CHUNK)
plt.setp(ax1, xticks=[0, CHUNK, 2 * CHUNK], yticks=[0, 128, 255])
# plt.setp(ax1, xticks=[0, CHUNK, 2 * CHUNK], yticks=[-AMPLITUDE_LIMIT, 0, AMPLITUDE_LIMIT])

# format spectrum axes
ax2.set_xlim(20, RATE / 2)

print('stream started')

# show the plot
# plt.show(block=False)

# for measuring frame rate
frame_count = 0
start_time = time.time()

while True:
    
    # binary data
    data = stream.read(CHUNK)  
    
    # convert data to integers, make np array, then offset it by 127
#     data_int = struct.unpack(str(2 * CHUNK) + 'B', data)
    
    # create np array and offset by 128
    # the following doesn't produce any proper waveform, only noise like and no response 
    # to sound (talking, music, taps...)
    # data_np = np.array(data_int, dtype='b')[::2] + 128
    # change to
    # see : https://github.com/markjay4k/Audio-Spectrum-Analyzer-in-Python/issues/5
    # and https://github.com/markjay4k/Audio-Spectrum-Analyzer-in-Python/issues/2
    data_np = (np.frombuffer(data, dtype='<i2') / max(data)) + 128
#     data_np = np.frombuffer(data, dtype='h')
    
    line.set_ydata(data_np)
    
    # compute FFT and update line
#     yf = fft(data_int)
#     line_fft.set_ydata(np.abs(yf[0:CHUNK])  / (128 * CHUNK))
    
    yf = fft(data_np)
    line_fft.set_ydata(np.abs(yf[0:CHUNK])  / (128 * CHUNK)) #(512 * CHUNK))
    
    # update figure canvas
    try:
        fig.canvas.draw()
        fig.canvas.flush_events()
        frame_count += 1
        
    except TclError:
        
        # calculate average frame rate
        frame_rate = frame_count / (time.time() - start_time)
        
        print('stream stopped')
        print('average frame rate = {:.0f} FPS'.format(frame_rate))
        break
# Out:
# ALSA lib pcm_dsnoop.c:638:(snd_pcm_dsnoop_open) unable to open slave
# ALSA lib pcm_dmix.c:1075:(snd_pcm_dmix_open) unable to open slave
# ALSA lib pcm.c:2660:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.rear
# ALSA lib pcm.c:2660:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.center_lfe
# ALSA lib pcm.c:2660:(snd_pcm_open_noupdate) Unknown PCM cards.pcm.side
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_oss.c:377:(_snd_pcm_oss_open) Unknown field port
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# ALSA lib pcm_usb_stream.c:486:(_snd_pcm_usb_stream_open) Invalid type for card
# ALSA lib pcm_dmix.c:1075:(snd_pcm_dmix_open) unable to open slave
# stream started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 58>()
#      82 # update figure canvas
#      83 try:
# ...
